# %%
import pandas as pd

# %%
df=pd.read_csv("revenue.csv")

# %%
df.head()
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6

# %%
df.plot(x ='company', y='revenue', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='company'>

# %%
df.plot(x='company' , y='revenue' , kind='bar', logy=True)
# Out:
# <AxesSubplot:xlabel='company'>

# %%
// Program to read data from the csv file and make a scatter chart

# %%
import pandas as p

# %%
d=p.read_csv("data.csv")
d.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
d.plot(kind='scatter', x='Maxpulse', y='Calories')
# Out:
# <AxesSubplot:xlabel='Maxpulse', ylabel='Calories'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')

df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

plt.show()

# %%
import pandas as ps

# %%
df=ps.read_csv('income.csv')

# %%
df.head(10)
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6
# 5        Vedanta     11.3

# %%
df.plot(kind='bar', x='company', y='revenue',logy=True)
# Out:
# <AxesSubplot:xlabel='company'>
